# %% [markdown]
# # Exploratory Data Analysis - Công Thức Nấu Ăn
# Phân tích dữ liệu các công thức nấu ăn từ DienmayXanh

# %% [markdown]
# ## Khai báo thư viện

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (12, 6)
sns.set_style("whitegrid")

# %%
df_urls = pd.read_csv('recipe_urls.csv')

with open('recipes_detail.json', 'r', encoding='utf-8') as f:
    recipes_detail = json.load(f)

with open('unique_ingredients.json', 'r', encoding='utf-8') as f:
    unique_ingredients = json.load(f)

with open('unique_dishes.json', 'r', encoding='utf-8') as f:
    unique_dishes = json.load(f)

with open('ingredients_synonyms_qwen.json', 'r', encoding='utf-8') as f:
    ingredients_synonyms = json.load(f)

df_recipes = pd.DataFrame(recipes_detail)

print("Dữ liệu đã được tải thành công")
print(f"Số tệp URL: {len(df_urls)}")
print(f"Số công thức nấu: {len(recipes_detail)}")
print(f"Số nguyên liệu duy nhất: {len(unique_ingredients)}")
print(f"Số món ăn duy nhất: {len(unique_dishes)}")
# Out:
# Dữ liệu đã được tải thành công
# Số tệp URL: 14502
# Số công thức nấu: 13624
# Số nguyên liệu duy nhất: 7950
# Số món ăn duy nhất: 10012

# %% [markdown]
# ## Tổng Quan Tập Dữ Liệu

# %%
print("THỐNG KÊ TỔNG QUÁT")

print(f"\nFile URLs:")
print(f"  - Số dòng: {len(df_urls)}")
print(f"  - Số cột: {df_urls.shape[1]}")
print(f"  - Tên cột: {list(df_urls.columns)}")

print(f"\nFile Recipes Detail:")
print(f"  - Số công thức: {len(recipes_detail)}")
print(f"  - Các trường trong mỗi công thức: {list(recipes_detail[0].keys()) if recipes_detail else 'N/A'}")

print(f"\nFile Unique Ingredients:")
print(f"  - Tổng số nguyên liệu: {len(unique_ingredients)}")
print(f"  - Loại dữ liệu: {type(unique_ingredients)}")

print(f"\nFile Unique Dishes:")
print(f"  - Tổng số món ăn: {len(unique_dishes)}")
print(f"  - Loại dữ liệu: {type(unique_dishes)}")

print(f"\nFile Ingredients Synonyms:")
print(f"  - Số nguyên liệu có đồng nghĩa: {len(ingredients_synonyms)}")
print(f"  - Loại dữ liệu: {type(ingredients_synonyms)}")
# Out:
# ============================================================
# THỐNG KÊ TỔNG QUÁT
# ============================================================
#
# File URLs:
#   - Số dòng: 14502
#   - Số cột: 2
#   - Tên cột: ['category', 'url']
#
# File Recipes Detail:
#   - Số công thức: 13624
#   - Các trường trong mỗi công thức: ['dish_name', 'url', 'servings', 'prep_time', 'cook_time', 'difficulty', 'views', 'ingredients', 'instructions', 'category']
#
# File Unique Ingredients:
#   - Tổng số nguyên liệu: 7950
#   - Loại dữ liệu: <class 'list'>
#
# File Unique Dishes:
#   - Tổng số món ăn: 10012
#   - Loại dữ liệu: <class 'list'>
#
# File Ingredients Synonyms:
#   - Số nguyên liệu có đồng nghĩa: 7950
#   - Loại dữ liệu: <class 'list'>

# %% [markdown]
# ## Phân Tích Chi Tiết Dữ Liệu Recipes

# %%
print(f"\nKích thước: {df_recipes.shape[0]} hàng x {df_recipes.shape[1]} cột")
print(f"\nTên các cột:")
for i, col in enumerate(df_recipes.columns, 1):
    print(f"  {i}. {col}")

print(f"\nDữ liệu thiếu:")
missing = df_recipes.isnull().sum()
missing_percent = (df_recipes.isnull().sum() / len(df_recipes)) * 100
for col in df_recipes.columns:
    print(f"  {col}: {missing[col]} ({missing_percent[col]:.2f}%)")

print(f"\nKiểu dữ liệu các cột:")
print(df_recipes.dtypes)

print(f"\nMột số dòng dữ liệu mẫu:")
df_recipes.head(3)
# Out:
# Kích thước: 13624 hàng x 10 cột
#
# Tên các cột:
#   1. dish_name
#   2. url
#   3. servings
#   4. prep_time
#   5. cook_time
#   6. difficulty
#   7. views
#   8. ingredients
#   9. instructions
#   10. category
#
# Dữ liệu thiếu:
#   dish_name: 0 (0.00%)
#   url: 0 (0.00%)
#   servings: 7 (0.05%)
#   prep_time: 0 (0.00%)
#   cook_time: 2079 (15.26%)
#   difficulty: 0 (0.00%)
#   views: 42 (0.31%)
#   ingredients: 0 (0.00%)
#   instructions: 0 (0.00%)
#   category: 0 (0.00%)
#
# Kiểu dữ liệu các cột:
# dish_name           str
# url                 str
# servings            str
# prep_time           str
# cook_time           str
# difficulty          str
# views           float64
# ingredients      object
# instructions     object
# category            str
# dtype: object
#
# Một số dòng dữ liệu mẫu:
#                 dish_name                                                url  \
# 0          Vịt quay tỳ bà  https://www.dienmayxanh.com/vao-bep/cach-lam-v...
# 1  Dẻ sườn bò nướng sa tế  https://www.dienmayxanh.com/vao-bep/cong-thuc-...
# 2   thịt heo quay tại nhà  https://www.dienmayxanh.com/vao-bep/cach-lam-t...
#
#   servings prep_time      cook_time  difficulty  views  \
# 0      4-5    10 giờ        25 phút         Khó   16.0
# 1      2-3   20 phút  1 giờ 20 phút          Dễ    1.0
# 2      800   25 phút          1 giờ  Trung bình    1.0
#
#                                          ingredients  \
# 0  [{'name': 'Vịt', 'quantity': 1.0, 'unit': 'con...
# 1  [{'name': 'Dẻ sườn bò', 'quantity': 500.0, 'un...
# 2  [{'name': 'Thịt ba rọi', 'quantity': 800.0, 'u...
#
#                                         instructions   category
# 0  [{'step_title': 'Sơ chế và lọc xương vịt', 'co...  Món nướng
# 1  [{'step_title': 'Sơ chế và phi thơm hành tỏi',...  Món nướng
# 2  [{'step_title': 'Sơ chế thịt ba rọi', 'content...  Món nướng

# %% [markdown]
# ### Thống Kê Mô Tả cho Các Biến Số

# %%
numeric_cols = df_recipes.select_dtypes(include=[np.number]).columns.tolist()

if numeric_cols:
    print("\n" + "=" * 60)
    print("THỐNG KÊ CÁC BIẾN SỐ")
    print("=" * 60)
    
    stats_df = df_recipes[numeric_cols].describe().T
    stats_df.columns = ['Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max']
    
    print("\nThống kê cơ bản (Mean, Median, Std, Min, Max):")
    print(stats_df.to_string())
    
    print("\n\nPhương sai (Variance):")
    for col in numeric_cols:
        variance = df_recipes[col].var()
        print(f"  {col}: {variance:.4f}")
    
    print("\n\nKhoảng tứ phân vị (IQR):")
    for col in numeric_cols:
        q1 = df_recipes[col].quantile(0.25)
        q3 = df_recipes[col].quantile(0.75)
        iqr = q3 - q1
        print(f"  {col}: Q1={q1:.2f}, Q3={q3:.2f}, IQR={iqr:.2f}")
else:
    print("Không có biến số trong cột, hoặc tất cả các cột là chuỗi ký tự")
# Out:
# ============================================================
# THỐNG KÊ CÁC BIẾN SỐ
# ============================================================
#
# Thống kê cơ bản (Mean, Median, Std, Min, Max):
#          Count          Mean           Std  Min      25%     50%       75%        Max
# views  13582.0  22479.968193  59074.378059  1.0  2086.25  6445.0  19057.75  1331941.0
#
#
# Phương sai (Variance):
#   views: 3489782143.1002
#
#
# Khoảng tứ phân vị (IQR):
#   views: Q1=2086.25, Q3=19057.75, IQR=16971.50

# %% [markdown]
# box plot

# %% [markdown]
# ## Phân Bố dữ liệu theo Từng Thuộc Tính

# %%
numeric_cols = df_recipes.select_dtypes(include=[np.number]).columns.tolist()

if numeric_cols:
    for col in numeric_cols:
        print(f"\n{col}:")
        print(f"  Giá trị nhỏ nhất: {df_recipes[col].min():.2f}")
        print(f"  Giá trị lớn nhất: {df_recipes[col].max():.2f}")
        print(f"  Trung bình: {df_recipes[col].mean():.2f}")
        print(f"  Trung vị: {df_recipes[col].median():.2f}")
        print(f"  Độ lệch chuẩn: {df_recipes[col].std():.2f}")
        
        skewness = df_recipes[col].skew()
        print(f"  Độ skew: {skewness:.2f}")
        if abs(skewness) < 0.5:
            print(f"    -> Phân bố gần như đối xứng")
        elif skewness > 0:
            print(f"    -> Phân bố lệch phải (positive skew)")
        else:
            print(f"    -> Phân bố lệch trái (negative skew)")

object_cols = df_recipes.select_dtypes(include=['object']).columns.tolist()

if object_cols:
    print(f"\n{'=' * 60}")
    print("PHÂN BỐ CÁC BIẾN PHÂN LOẠI")
    print(f"{'=' * 60}")
    
    for col in object_cols:
        if col not in ['ingredients', 'instructions']:
            print(f"\n{col}:")
            try:
                value_counts = df_recipes[col].value_counts(dropna=False)
                print(f"  Số giá trị duy nhất: {df_recipes[col].nunique(dropna=False)}")
                print(f"  Top 5 giá trị phổ biến nhất:")
                for val, count in value_counts.head(5).items():
                    percent = (count / len(df_recipes)) * 100
                    print(f"    - {val}: {count} ({percent:.2f}%)")
            except:
                print(f"  Không thể phân tích cột này")
# Out:
# ============================================================
# PHÂN BỐ DỮ LIỆU THEO TỪNG THUỘC TÍNH
# ============================================================
#
# views:
#   Giá trị nhỏ nhất: 1.00
#   Giá trị lớn nhất: 1331941.00
#   Trung bình: 22479.97
#   Trung vị: 6445.00
#   Độ lệch chuẩn: 59074.38
#   Độ skew: 8.56
#     -> Phân bố lệch phải (positive skew)
#
# ============================================================
# PHÂN BỐ CÁC BIẾN PHÂN LOẠI
# ============================================================
#
# dish_name:
#   Số giá trị duy nhất: 10013
#   Top 5 giá trị phổ biến nhất:
#     - Sốt Teriyaki Nhật Bản: 20 (0.15%)
#     - Trân châu đường đen: 11 (0.08%)
#     - Kem cheese từ phô mai con bò cười: 8 (0.06%)
#     - Sữa chua úp ngược: 7 (0.05%)
#     - Trân châu từ bột nếp: 7 (0.05%)
#
# url:
#   Số giá trị duy nhất: 10253
#   Top 5 giá trị phổ biến nhất:
#     - https://www.dienmayxanh.com/vao-bep/3-cach-lam-so-huyet-xao-me-so-huyet-rang-muoi-so-huyet-nuong-03014: 4 (0.03%)
#     - https://www.dienmayxanh.com/vao-bep/cach-lam-bo-wellington-moi-la-cho-ban-tiec-giang-sinh-them-05397: 4 (0.03%)
#     - https://www.dienmayxanh.com/vao-bep/cach-lam-4-mon-nhau-tu-long-lon-nhanh-don-gian-01648: 4 (0.03%)
#     - https://www.dienmayxanh.com/vao-bep/2-cach-lam-gio-thu-gio-xao-de-lam-gion-ngon-01453: 4 (0.03%)
#     - https://www.dienmayxanh.com/vao-bep/cach-lam-nem-hai-san-chay-thom-ngon-gion-rum-cho-ngay-ram-12522: 4 (0.03%)
#
# servings:
#   Số giá trị duy nhất: 108
#   Top 5 giá trị phổ biến nhất:
#     - 4: 5001 (36.71%)
#     - 2: 3161 (23.20%)
#     - 3: 1950 (14.31%)
#     - 1: 1066 (7.82%)
#     - 5: 413 (3.03%)
#
# prep_time:
#   Số giá trị duy nhất: 81
#   Top 5 giá trị phổ biến nhất:
#     - 15 phút: 2897 (21.26%)
#     - 10 phút: 2390 (17.54%)
#     - 30 phút: 2323 (17.05%)
#     - 20 phút: 2122 (15.58%)
#     - 5 phút: 836 (6.14%)
#
# cook_time:
#   Số giá trị duy nhất: 91
#   Top 5 giá trị phổ biến nhất:
#     - 30 phút: 2611 (19.16%)
#     - nan: 2079 (15.26%)
#     - 20 phút: 1762 (12.93%)
#     - 15 phút: 1576 (11.57%)
#     - 10 phút: 1039 (7.63%)
#
# difficulty:
#   Số giá trị duy nhất: 3
#   Top 5 giá trị phổ biến nhất:
#     - Dễ: 11908 (87.40%)
#     - Trung bình: 1678 (12.32%)
#     - Khó: 38 (0.28%)
#
# category:
#   Số giá trị duy nhất: 20
#   Top 5 giá trị phổ biến nhất:
#     - Ăn vặt: 1602 (11.76%)
#     - Món chiên: 1458 (10.70%)
#     - Món xào: 1304 (9.57%)
#     - Món kho: 940 (6.90%)
#     - Thức uống: 871 (6.39%)

# %% [markdown]
# ## Phân Tích Phân Bố Nhãn

# %%
print("\n" + "=" * 60)
print("PHÂN TÍCH PHÂN BỐ NHÃN")
print("=" * 60)

object_cols = df_recipes.select_dtypes(include=['object']).columns.tolist()

if object_cols:
    for col in object_cols:
        if col not in ['dish_name','url','ingredients', 'instructions']:
            print(f"\n{col}:")
            try:
                value_counts = df_recipes[col].value_counts(dropna=False)
                print(f"  Tổng số lớp/nhãn: {len(value_counts)}")
                print(f"  Phân bố các nhãn:")
                
                for val, count in value_counts.items():
                    percent = (count / len(df_recipes)) * 100
                    try:
                        if pd.isna(val):
                            print(f"    - Missing/NaN: {count} ({percent:.2f}%)")
                        else:
                            print(f"    - {val}: {count} ({percent:.2f}%)")
                    except:
                        print(f"    - {str(val)[:50]}: {count} ({percent:.2f}%)")
                
                if len(value_counts) > 1:
                    max_count = value_counts.max()
                    min_count = value_counts.min()
                    imbalance_ratio = max_count / min_count if min_count > 0 else float('inf')
                    print(f"\n  Tỉ lệ mất cân bằng (max/min): {imbalance_ratio:.2f}")
                    
                    if imbalance_ratio > 5:
                        print(f"    -> Dữ liệu BỊ MẤT CÂN BẰNG NGHIÊM TRỌNG")
                    elif imbalance_ratio > 2:
                        print(f"    -> Dữ liệu CÓ DẤU HIỆU MẤT CÂN BẰNG")
                    else:
                        print(f"    -> Dữ liệu CÂN BẰNG TỪ TỰC")
            except Exception as e:
                print(f"  Lỗi phân tích: {str(e)}")
# Out:
# ============================================================
# PHÂN TÍCH PHÂN BỐ NHÃN
# ============================================================
#
# servings:
#   Tổng số lớp/nhãn: 108
#   Phân bố các nhãn:
#     - 4: 5001 (36.71%)
#     - 2: 3161 (23.20%)
#     - 3: 1950 (14.31%)
#     - 1: 1066 (7.82%)
#     - 5: 413 (3.03%)
#     - 6: 287 (2.11%)
#     - 2-3: 275 (2.02%)
#     - 3-4: 225 (1.65%)
#     - 4-6: 153 (1.12%)
#     - 10: 112 (0.82%)
#     - 8: 101 (0.74%)
#     - 1-2: 93 (0.68%)
#     - 4-5: 91 (0.67%)
#     - 500: 64 (0.47%)
#     - 6-8: 43 (0.32%)
#     - 12: 38 (0.28%)
#     - 300: 34 (0.25%)
#     - 200: 33 (0.24%)
#     - 2-4: 30 (0.22%)
#     - 20: 25 (0.18%)
#     - 15: 25 (0.18%)
#     - 5-6: 23 (0.17%)
#     - 400: 22 (0.16%)
#     - 7: 21 (0.15%)
#     - 30: 15 (0.11%)
#     - 04: 15 (0.11%)
#     - 15-20: 15 (0.11%)
#     - 800: 14 (0.10%)
#     - 150: 14 (0.10%)
#     - 600: 14 (0.10%)
#     - 250: 14 (0.10%)
#     - 700: 11 (0.08%)
#     - 50: 9 (0.07%)
#     - 100: 9 (0.07%)
#     - 10-12: 9 (0.07%)
#     - 8-10: 9 (0.07%)
#     - 18: 9 (0.07%)
#     - 25: 8 (0.06%)
#     - 16: 8 (0.06%)
#     - Missing/NaN: 7 (0.05%)
#     - 03: 7 (0.05%)
#     - 60: 7 (0.05%)
#     - 900: 6 (0.04%)
#     - 10-15: 6 (0.04%)
#     - 14: 6 (0.04%)
#     - 9: 6 (0.04%)
#     - 40: 6 (0.04%)
#     - 24: 5 (0.04%)
#     - 20-25: 5 (0.04%)
#     - 2-1: 4 (0.03%)
#     - 02: 4 (0.03%)
#     - 5-2: 3 (0.02%)
#     - 0: 3 (0.02%)
#     - 10-11: 3 (0.02%)
#     - 750: 3 (0.02%)
#     - 44: 3 (0.02%)
#     - 850: 3 (0.02%)
#     - 5-7: 3 (0.02%)
#     - 13: 3 (0.02%)
#     - 16-20: 3 (0.02%)
#     - 430: 3 (0.02%)
#     - 33: 3 (0.02%)
#     - 120: 3 (0.02%)
#     - 5-12: 2 (0.01%)
#     - 25-30: 2 (0.01%)
#     - 30-35: 2 (0.01%)
#     - 16-17: 2 (0.01%)
#     - 9-10: 2 (0.01%)
#     - 32: 2 (0.01%)
#     - 7-8: 2 (0.01%)
#     - 590: 2 (0.01%)
#     - 11: 2 (0.01%)
#     - 300-400: 2 (0.01%)
#     - 24-26: 2 (0.01%)
#     - 140: 2 (0.01%)
#     - 200-300: 2 (0.01%)
#     - 400-500: 2 (0.01%)
#     - 350: 2 (0.01%)
#     - 255: 1 (0.01%)
#     - 30-40: 1 (0.01%)
#     - 70: 1 (0.01%)
#     - 825: 1 (0.01%)
#     - 970: 1 (0.01%)
#     - 3-5: 1 (0.01%)
#     - 35-40: 1 (0.01%)
#     - 18-20: 1 (0.01%)
#     - 6-10: 1 (0.01%)
#     - 05: 1 (0.01%)
#     - 21: 1 (0.01%)
#     - 440-500: 1 (0.01%)
#     - 110: 1 (0.01%)
#     - 13-16: 1 (0.01%)
#     - 36: 1 (0.01%)
#     - 33-35: 1 (0.01%)
#     - 180: 1 (0.01%)
#     - 2-2: 1 (0.01%)
#     - 80: 1 (0.01%)
#     - 43: 1 (0.01%)
#     - 335: 1 (0.01%)
#     - 6-7: 1 (0.01%)
#     - 3-3: 1 (0.01%)
#     - 8-9: 1 (0.01%)
#     - 45: 1 (0.01%)
#     - 450: 1 (0.01%)
#     - 50-60: 1 (0.01%)
#     - 500-750: 1 (0.01%)
#     - 22-23: 1 (0.01%)
#     - 360: 1 (0.01%)
#
#   Tỉ lệ mất cân bằng (max/min): 5001.00
#     -> Dữ liệu BỊ MẤT CÂN BẰNG NGHIÊM TRỌNG
#
# prep_time:
#   Tổng số lớp/nhãn: 81
#   Phân bố các nhãn:
#     - 15 phút: 2897 (21.26%)
#     - 10 phút: 2390 (17.54%)
#     - 30 phút: 2323 (17.05%)
#     - 20 phút: 2122 (15.58%)
#     - 5 phút: 836 (6.14%)
#     - 1 giờ: 659 (4.84%)
#     - 40 phút: 533 (3.91%)
#     - 25 phút: 378 (2.77%)
#     - 45 phút: 335 (2.46%)
#     - 2 giờ: 164 (1.20%)
#     - 35 phút: 115 (0.84%)
#     - 50 phút: 111 (0.81%)
#     - 1 giờ 30 phút: 102 (0.75%)
#     - 4 giờ: 64 (0.47%)
#     - 3 giờ: 52 (0.38%)
#     - 2 giờ 30 phút: 46 (0.34%)
#     - 1 giờ 10 phút: 40 (0.29%)
#     - 6 giờ: 36 (0.26%)
#     - 1 giờ 15 phút: 35 (0.26%)
#     - 1 giờ 20 phút: 35 (0.26%)
#     - 8 giờ: 34 (0.25%)
#     - 5 giờ: 34 (0.25%)
#     - 7 phút: 22 (0.16%)
#     - 3 phút: 18 (0.13%)
#     - 12 giờ: 17 (0.12%)
#     - 2 phút: 14 (0.10%)
#     - 4 giờ 30 phút: 13 (0.10%)
#     - 2 giờ 10 phút: 10 (0.07%)
#     - 2 giờ 15 phút: 10 (0.07%)
#     - 4 phút: 10 (0.07%)
#     - 1 phút: 9 (0.07%)
#     - 12 phút: 9 (0.07%)
#     - 8 phút: 8 (0.06%)
#     - 3 giờ 10 phút: 8 (0.06%)
#     - 1 giờ 45 phút: 8 (0.06%)
#     - 6 giờ 30 phút: 8 (0.06%)
#     - 10 giờ: 7 (0.05%)
#     - 2 giờ 20 phút: 6 (0.04%)
#     - 20 giờ: 6 (0.04%)
#     - 23 giờ: 6 (0.04%)
#     - 16 phút: 6 (0.04%)
#     - 55 phút: 5 (0.04%)
#     - 6 phút: 5 (0.04%)
#     - 15 giờ: 5 (0.04%)
#     - 7 giờ: 4 (0.03%)
#     - 3 giờ 30 phút: 4 (0.03%)
#     - 8 giờ 10 phút: 4 (0.03%)
#     - 2 giờ 55 phút: 4 (0.03%)
#     - 2 giờ 45 phút: 3 (0.02%)
#     - 3 giờ 15 phút: 3 (0.02%)
#     - 1 giờ 40 phút: 3 (0.02%)
#     - 5 giờ 10 phút: 3 (0.02%)
#     - 11 giờ: 3 (0.02%)
#     - 7 giờ 30 phút: 3 (0.02%)
#     - 5 giờ 15 phút: 2 (0.01%)
#     - 4 giờ 20 phút: 2 (0.01%)
#     - 6 giờ 15 phút: 2 (0.01%)
#     - 3 giờ 20 phút: 2 (0.01%)
#     - 4 giờ 15 phút: 2 (0.01%)
#     - 1 giờ 25 phút: 2 (0.01%)
#     - 1 giờ 50 phút: 2 (0.01%)
#     - 16 giờ: 2 (0.01%)
#     - 4 giờ 10 phút: 2 (0.01%)
#     - 8 giờ 30 phút: 2 (0.01%)
#     - 2 giờ 40 phút: 2 (0.01%)
#     - 9 phút: 2 (0.01%)
#     - 29 phút: 1 (0.01%)
#     - 47 phút: 1 (0.01%)
#     - 1 giờ 5 phút: 1 (0.01%)
#     - 14 phút: 1 (0.01%)
#     - 59 phút: 1 (0.01%)
#     - 15 giờ 30 phút: 1 (0.01%)
#     - 8 giờ 40 phút: 1 (0.01%)
#     - 21 phút: 1 (0.01%)
#     - 12 giờ 20 phút: 1 (0.01%)
#     - 13 phút: 1 (0.01%)
#     - 2 giờ 25 phút: 1 (0.01%)
#     - 6 giờ 5 phút: 1 (0.01%)
#     - 8 giờ 20 phút: 1 (0.01%)
#     - 3 giờ 45 phút: 1 (0.01%)
#     - 13 giờ: 1 (0.01%)
#
#   Tỉ lệ mất cân bằng (max/min): 2897.00
#     -> Dữ liệu BỊ MẤT CÂN BẰNG NGHIÊM TRỌNG
#
# cook_time:
#   Tổng số lớp/nhãn: 91
#   Phân bố các nhãn:
#     - 30 phút: 2611 (19.16%)
#     - Missing/NaN: 2079 (15.26%)
#     - 20 phút: 1762 (12.93%)
#     - 15 phút: 1576 (11.57%)
#     - 10 phút: 1039 (7.63%)
#     - 1 giờ: 764 (5.61%)
#     - 40 phút: 664 (4.87%)
#     - 45 phút: 617 (4.53%)
#     - 25 phút: 546 (4.01%)
#     - 5 phút: 431 (3.16%)
#     - 50 phút: 249 (1.83%)
#     - 35 phút: 240 (1.76%)
#     - 1 giờ 30 phút: 206 (1.51%)
#     - 2 giờ: 113 (0.83%)
#     - 1 giờ 15 phút: 73 (0.54%)
#     - 1 giờ 10 phút: 57 (0.42%)
#     - 1 giờ 20 phút: 47 (0.34%)
#     - 3 giờ: 42 (0.31%)
#     - 4 giờ: 37 (0.27%)
#     - 7 phút: 34 (0.25%)
#     - 55 phút: 34 (0.25%)
#     - 1 giờ 40 phút: 31 (0.23%)
#     - 1 giờ 45 phút: 27 (0.20%)
#     - 2 giờ 30 phút: 26 (0.19%)
#     - 8 phút: 24 (0.18%)
#     - 12 phút: 17 (0.12%)
#     - 6 giờ: 15 (0.11%)
#     - 5 giờ: 15 (0.11%)
#     - 1 phút: 13 (0.10%)
#     - 1 giờ 50 phút: 12 (0.09%)
#     - 2 phút: 12 (0.09%)
#     - 3 phút: 12 (0.09%)
#     - 2 giờ 15 phút: 10 (0.07%)
#     - 8 giờ: 10 (0.07%)
#     - 6 phút: 9 (0.07%)
#     - 2 giờ 45 phút: 9 (0.07%)
#     - 7 giờ: 8 (0.06%)
#     - 17 phút: 7 (0.05%)
#     - 1 giờ 5 phút: 7 (0.05%)
#     - 3 giờ 15 phút: 7 (0.05%)
#     - 23 phút: 6 (0.04%)
#     - 8 giờ 30 phút: 6 (0.04%)
#     - 23 giờ: 6 (0.04%)
#     - 18 phút: 5 (0.04%)
#     - 1 giờ 35 phút: 5 (0.04%)
#     - 4 giờ 30 phút: 5 (0.04%)
#     - 2 giờ 20 phút: 5 (0.04%)
#     - 4 phút: 5 (0.04%)
#     - 2 giờ 50 phút: 4 (0.03%)
#     - 3 giờ 50 phút: 4 (0.03%)
#     - 14 giờ: 4 (0.03%)
#     - 9 giờ: 4 (0.03%)
#     - 5 giờ 30 phút: 4 (0.03%)
#     - 3 giờ 30 phút: 3 (0.02%)
#     - 44 phút: 3 (0.02%)
#     - 48 phút: 3 (0.02%)
#     - 6 giờ 30 phút: 3 (0.02%)
#     - 10 giờ: 3 (0.02%)
#     - 3 giờ 40 phút: 3 (0.02%)
#     - 2 giờ 35 phút: 3 (0.02%)
#     - 23 giờ 59 phút: 3 (0.02%)
#     - 12 giờ: 3 (0.02%)
#     - 39 phút: 2 (0.01%)
#     - 2 giờ 55 phút: 2 (0.01%)
#     - 13 phút: 2 (0.01%)
#     - 22 phút: 2 (0.01%)
#     - 1 giờ 25 phút: 2 (0.01%)
#     - 37 phút: 2 (0.01%)
#     - 3 giờ 20 phút: 2 (0.01%)
#     - 59 phút: 2 (0.01%)
#     - 4 giờ 5 phút: 2 (0.01%)
#     - 58 phút: 2 (0.01%)
#     - 4 giờ 10 phút: 2 (0.01%)
#     - 9 giờ 30 phút: 2 (0.01%)
#     - 15 giờ: 2 (0.01%)
#     - 11 phút: 1 (0.01%)
#     - 16 phút: 1 (0.01%)
#     - 2 giờ 10 phút: 1 (0.01%)
#     - 2 giờ 40 phút: 1 (0.01%)
#     - 3 giờ 5 phút: 1 (0.01%)
#     - 4 giờ 20 phút: 1 (0.01%)
#     - 7 giờ 20 phút: 1 (0.01%)
#     - 8 giờ 15 phút: 1 (0.01%)
#     - 15 giờ 30 phút: 1 (0.01%)
#     - 10 giờ 15 phút: 1 (0.01%)
#     - 1 giờ 55 phút: 1 (0.01%)
#     - 5 giờ 20 phút: 1 (0.01%)
#     - 23 giờ 30 phút: 1 (0.01%)
#     - 8 giờ 10 phút: 1 (0.01%)
#     - 7 giờ 10 phút: 1 (0.01%)
#     - 11 giờ: 1 (0.01%)
#
#   Tỉ lệ mất cân bằng (max/min): 2611.00
#     -> Dữ liệu BỊ MẤT CÂN BẰNG NGHIÊM TRỌNG
#
# difficulty:
#   Tổng số lớp/nhãn: 3
#   Phân bố các nhãn:
#     - Dễ: 11908 (87.40%)
#     - Trung bình: 1678 (12.32%)
#     - Khó: 38 (0.28%)
#
#   Tỉ lệ mất cân bằng (max/min): 313.37
#     -> Dữ liệu BỊ MẤT CÂN BẰNG NGHIÊM TRỌNG
#
# category:
#   Tổng số lớp/nhãn: 20
#   Phân bố các nhãn:
#     - Ăn vặt: 1602 (11.76%)
#     - Món chiên: 1458 (10.70%)
#     - Món xào: 1304 (9.57%)
#     - Món kho: 940 (6.90%)
#     - Thức uống: 871 (6.39%)
#     - Món hấp: 820 (6.02%)
#     - Món nướng: 769 (5.64%)
#     - Món tráng miệng: 750 (5.50%)
#     - Món chay: 743 (5.45%)
#     - Ngày lễ Tết: 708 (5.20%)
#     - Món từ gà: 672 (4.93%)
#     - Món từ bò: 594 (4.36%)
#     - Món gỏi - salad: 516 (3.79%)
#     - Món cuốn - trộn: 477 (3.50%)
#     - Món cháo: 363 (2.66%)
#     - Món khô - mắm: 306 (2.25%)
#     - Món lẩu: 272 (2.00%)
#     - Sinh tố: 157 (1.15%)
#     - Trà sữa: 152 (1.12%)
#     - Nước ép: 150 (1.10%)
#
#   Tỉ lệ mất cân bằng (max/min): 10.68
#     -> Dữ liệu BỊ MẤT CÂN BẰNG NGHIÊM TRỌNG

# %% [markdown]
# ## Phân Tích Nguyên Liệu và Món Ăn

# %%
print("\n" + "=" * 60)
print("PHÂN TÍCH NGUYÊN LIỆU")
print("=" * 60)

print(f"\nTổng số nguyên liệu duy nhất: {len(unique_ingredients)}")
print(f"Kiểu dữ liệu: {type(unique_ingredients)}")

print(f"\n{'=' * 60}")
print("PHÂN TÍCH MÓN ĂN")
print("=" * 60)

print(f"\nTổng số món ăn duy nhất: {len(unique_dishes)}")
print(f"Kiểu dữ liệu: {type(unique_dishes)}")

if isinstance(unique_dishes, list) and len(unique_dishes) > 0:
    print(f"\n10 món ăn đầu tiên:")
    for i, dish in enumerate(unique_dishes[:10], 1):
        print(f"  {i}. {dish}")
# Out:
# ============================================================
# PHÂN TÍCH NGUYÊN LIỆU
# ============================================================
#
# Tổng số nguyên liệu duy nhất: 7950
# Kiểu dữ liệu: <class 'list'>
#
# ============================================================
# PHÂN TÍCH MÓN ĂN
# ============================================================
#
# Tổng số món ăn duy nhất: 10012
# Kiểu dữ liệu: <class 'list'>
#
# 10 món ăn đầu tiên:
#   1. Cơm chiên bò xào
#   2. Gỏi trái điều thịt heo
#   3. Bánh mì sandwich trứng chiên xúc xích
#   4. Bí nụ xào tỏi
#   5. Sò lụa xào me
#   6. Thạch chanh dây
#   7. Nem hải sản sốt mayonnaise
#   8. Cá nhám kho nghệ
#   9. Nấm rơm kho tương hột đậu hũ
#   10. Mận ngâm đường phèn

# %% [markdown]
# ## Phân Tích Chi Tiết Công Thức

# %%
print("\n" + "=" * 60)
print("PHÂN TÍCH CHI TIẾT CÔNG THỨC NẤU ĂN")
print("=" * 60)

if recipes_detail and len(recipes_detail) > 0:
    print(f"\nTổng số công thức: {len(recipes_detail)}")
    
    first_recipe = recipes_detail[0]
    print(f"\nCác trường dữ liệu trong mỗi công thức:")
    for i, key in enumerate(first_recipe.keys(), 1):
        print(f"  {i}. {key}")
    
    if 'ingredients' in first_recipe:
        ingredient_counts = []
        for recipe in recipes_detail:
            if 'ingredients' in recipe and recipe['ingredients']:
                if isinstance(recipe['ingredients'], list):
                    ingredient_counts.append(len(recipe['ingredients']))
                else:
                    ingredient_counts.append(1)
            else:
                ingredient_counts.append(0)
        
        if ingredient_counts:
            print(f"\nSố lượng nguyên liệu trong các công thức:")
            print(f"  - Trung bình: {np.mean(ingredient_counts):.2f}")
            print(f"  - Trung vị: {np.median(ingredient_counts):.2f}")
            print(f"  - Tối thiểu: {min(ingredient_counts)}")
            print(f"  - Tối đa: {max(ingredient_counts)}")
            print(f"  - Độ lệch chuẩn: {np.std(ingredient_counts):.2f}")
    
    if 'instructions' in first_recipe:
        instruction_counts = []
        for recipe in recipes_detail:
            if 'instructions' in recipe and recipe['instructions']:
                if isinstance(recipe['instructions'], list):
                    instruction_counts.append(len(recipe['instructions']))
                else:
                    instruction_counts.append(1)
            else:
                instruction_counts.append(0)
        
        if instruction_counts:
            print(f"\nSố lượng bước chế biến trong các công thức:")
            print(f"  - Trung bình: {np.mean(instruction_counts):.2f}")
            print(f"  - Trung vị: {np.median(instruction_counts):.2f}")
            print(f"  - Tối thiểu: {min(instruction_counts)}")
            print(f"  - Tối đa: {max(instruction_counts)}")
            print(f"  - Độ lệch chuẩn: {np.std(instruction_counts):.2f}")
    
    print(f"\nMột ví dụ công thức:")
    sample_recipe = recipes_detail[0]
    for key, value in sample_recipe.items():
        if isinstance(value, list) and len(str(value)) > 80:
            print(f"  {key}: [{len(value)} items]")
        elif isinstance(value, str) and len(value) > 100:
            print(f"  {key}: {value[:100]}...")
        else:
            print(f"  {key}: {value}")
# Out:
# ============================================================
# PHÂN TÍCH CHI TIẾT CÔNG THỨC NẤU ĂN
# ============================================================
#
# Tổng số công thức: 13624
#
# Các trường dữ liệu trong mỗi công thức:
#   1. dish_name
#   2. url
#   3. servings
#   4. prep_time
#   5. cook_time
#   6. difficulty
#   7. views
#   8. ingredients
#   9. instructions
#   10. category
#
# Số lượng nguyên liệu trong các công thức:
#   - Trung bình: 9.47
#   - Trung vị: 9.00
#   - Tối thiểu: 0
#   - Tối đa: 34
#   - Độ lệch chuẩn: 4.50
#
# Số lượng bước chế biến trong các công thức:
#   - Trung bình: 3.18
#   - Trung vị: 4.00
#   - Tối thiểu: 0
#   - Tối đa: 15
#   - Độ lệch chuẩn: 2.51
#
# Một ví dụ công thức:
#   dish_name: Vịt quay tỳ bà
#   url: https://www.dienmayxanh.com/vao-bep/cach-lam-vit-quay-ty-ba-da-gion-rum-mau-dep-thom-ngon-chuan-2417...
#   servings: 4-5
#   prep_time: 10 giờ
#   cook_time: 25 phút
#   difficulty: Khó
#   views: 16
#   ingredients: [17 items]
#   instructions: [6 items]
#   category: Món nướng

# %% [markdown]
# ## Tóm Tắt Kết Quả EDA

# %%
print("\n" + "=" * 60)
print("TÓM TẮT KẾT QUẢ PHÂN TÍCH DỮ LIỆU")
print("=" * 60)

print("\n1. TỔNG QUAN:")
print(f"   • Tập dữ liệu công thức: {df_recipes.shape[0]} hàng x {df_recipes.shape[1]} cột")
print(f"   • Số món ăn duy nhất: {len(unique_dishes)}")
print(f"   • Số nguyên liệu duy nhất: {len(unique_ingredients)}")
print(f"   • Số nguyên liệu có từ đồng nghĩa: {len(ingredients_synonyms)}")

missing_percent = (df_recipes.isnull().sum() / len(df_recipes) * 100).max()
print(f"   • Tỉ lệ dữ liệu thiếu tối đa: {missing_percent:.2f}%")

print("\n2. BIẾN SỐ:")
numeric_cols = df_recipes.select_dtypes(include=[np.number]).columns.tolist()
if numeric_cols:
    print(f"   • Số biến số: {len(numeric_cols)}")
    for col in numeric_cols:
        print(f"     - {col}: mean={df_recipes[col].mean():.2f}, "
              f"std={df_recipes[col].std():.2f}, "
              f"min={df_recipes[col].min():.2f}, max={df_recipes[col].max():.2f}")
else:
    print("   • Không có biến số trong dữ liệu công thức")

print("\n3. BIẾN PHÂN LOẠI:")
object_cols = df_recipes.select_dtypes(include=['object']).columns.tolist()
printable_cols = [col for col in object_cols if col not in ['ingredients', 'instructions']]
if printable_cols:
    print(f"   • Số biến phân loại (có thể phân tích): {len(printable_cols)}")
    for col in printable_cols:
        try:
            n_unique = df_recipes[col].nunique(dropna=False)
            print(f"     - {col}: {n_unique} giá trị duy nhất")
        except:
            print(f"     - {col}: Không thể tính")
else:
    print("   • Không có biến phân loại")

print("\n4. CÂN BẰNG DỮ LIỆU (theo Độ khó và Danh mục):")
for col in ['difficulty', 'category']:
    if col in printable_cols:
        try:
            value_counts = df_recipes[col].value_counts(dropna=False)
            if len(value_counts) > 1:
                max_count = value_counts.max()
                min_count = value_counts.min()
                imbalance_ratio = max_count / min_count if min_count > 0 else float('inf')
                status = "CÂN BẰNG" if imbalance_ratio < 2 else "MẤT CÂN BẰNG" if imbalance_ratio < 5 else "MẤT CÂN BẰNG NGHIÊM TRỌNG"
                print(f"   • {col}: {status} (Tỉ lệ {imbalance_ratio:.2f})")
        except:
            pass

print("\n5. ĐẶC ĐIỂM DỮ LIỆU CÔNG THỨC:")
ingredient_counts = []
for recipe in recipes_detail:
    if 'ingredients' in recipe and recipe['ingredients']:
        if isinstance(recipe['ingredients'], list):
            ingredient_counts.append(len(recipe['ingredients']))

if ingredient_counts:
    print(f"   • Số lượng nguyên liệu/công thức:")
    print(f"     - Trung bình: {np.mean(ingredient_counts):.2f}")
    print(f"     - Min-Max: {min(ingredient_counts)}-{max(ingredient_counts)}")
# Out:
# ============================================================
# TÓM TẮT KẾT QUẢ PHÂN TÍCH DỮ LIỆU
# ============================================================
#
# 1. TỔNG QUAN:
#    • Tập dữ liệu công thức: 13624 hàng x 10 cột
#    • Số món ăn duy nhất: 10012
#    • Số nguyên liệu duy nhất: 7950
#    • Số nguyên liệu có từ đồng nghĩa: 7950
#    • Tỉ lệ dữ liệu thiếu tối đa: 15.26%
#
# 2. BIẾN SỐ:
#    • Số biến số: 1
#      - views: mean=22479.97, std=59074.38, min=1.00, max=1331941.00
#
# 3. BIẾN PHÂN LOẠI:
#    • Số biến phân loại (có thể phân tích): 7
#      - dish_name: 10013 giá trị duy nhất
#      - url: 10253 giá trị duy nhất
#      - servings: 108 giá trị duy nhất
#      - prep_time: 81 giá trị duy nhất
#      - cook_time: 91 giá trị duy nhất
#      - difficulty: 3 giá trị duy nhất
#      - category: 20 giá trị duy nhất
#
# 4. CÂN BẰNG DỮ LIỆU (theo Độ khó và Danh mục):
#    • difficulty: MẤT CÂN BẰNG NGHIÊM TRỌNG (Tỉ lệ 313.37)
#    • category: MẤT CÂN BẰNG NGHIÊM TRỌNG (Tỉ lệ 10.68)
#
# 5. ĐẶC ĐIỂM DỮ LIỆU CÔNG THỨC:
#    • Số lượng nguyên liệu/công thức:
#      - Trung bình: 9.47
#      - Min-Max: 1-34
#
# ============================================================
# Phân tích EDA hoàn tất!
# ============================================================
